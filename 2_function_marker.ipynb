# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="time", data=tips);
# 이거에다 밑에 큰거 하나 추가해서.

# %%
color = 'cadetblue'

fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(15,13))
fig.suptitle('Pixel Population Histogram by Bin Numbers', fontsize=30)

sns.histplot(x=seaborn_pixel, ax=ax1, element="bars", color=color, bins=10)
ax1.set_xlabel('Pixel Value (binwidth=10)')

sns.histplot(x=seaborn_pixel, ax=ax2, element="bars", color=color, bins=100)
ax2.set_xlabel('Pixel Value (binwidth=100)')

sns.histplot(x=seaborn_pixel, ax=ax3, element="bars", color=color, discrete=True, bins=1000)
ax3.set_xlabel('Pixel Value (binwidth=1000)')


plt.subplots_adjust(hspace=0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-50b230a0d108> in <module>
#       4 fig.suptitle('Pixel Population Histogram by Bin Numbers', fontsize=30)
#       5
# ----> 6 sns.histplot(x=seaborn_pixel, ax=ax1, element="bars", color=color, bins=10)
#       7 ax1.set_xlabel('Pixel Value (binwidth=10)')
#       8
#
# NameError: name 'seaborn_pixel' is not defined

# %% [markdown]
# <img src="img/0_basic_PartsOfAFigure.png" width="600" height="600" align="left">
