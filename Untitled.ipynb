# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("./data/sample.xlsx")
data = data.drop("Unnamed: 0", axis=1)
print(len(data))
print(data.columns)
data.head()
# Out:
# 607
# Index(['CountryCode', 'AdType', 'Media', 'Product', 'TargetGroup2',
#        'Creative (Year)', 'Index Score', 'Impression', 'Click', 'Video50',
#        'Video100', 'Visit', 'WTB', 'RevisionVisit', 'RevisionWTB', 'Bounce',
#        'TotalAction', 'TOS', 'Pagelike', 'Postcomment', 'Postreaction',
#        'Postshare', 'Reuse', 'CPM', 'CPC', 'CTR', 'VisitRate', 'View50TR'],
#       dtype='object')
#   CountryCode  AdType Media Product TargetGroup2  \
# 0          AP  Banner  FBIG     REF    1st party
# 1          AP  Banner  FBIG     REF    1st party
# 2          AP  Banner  FBIG     REF    1st party
# 3          AP  Banner  FBIG     REF    1st party
# 4          AP  Banner  FBIG     REF    1st party
#
#                    Creative (Year)  Index Score  Impression  Click  Video50  \
# 0          C2-REF-N (2019, Action)  1242.650441      195978   2118        0
# 1            C3-REF (2019, Action)   882.990859       10534     72        0
# 2     C3-REF (2019, Consideration)   714.566795       46151    242        0
# 3  USP-Custom-Chill (2021, Action)  1246.247863       22913    274        0
# 4  USP-Fresh-Shield (2021, Action)   913.544042       34883    207        0
#
#    ...  Pagelike  Postcomment  Postreaction  Postshare  Reuse       CPM  \
# 0  ...         0           13           118          6      0  0.025689
# 1  ...         0            0             8          0      0  0.011961
# 2  ...         0            1            19          0      0  0.008537
# 3  ...         0            0            13          1      0  0.007990
# 4  ...         0            1            54          3      0  0.028301
#
#         CPC       CTR  VisitRate  View50TR
# 0  1.908488  0.010807   0.753069       0.0
# 1  1.750000  0.006835   0.708333       0.0
# 2  1.628099  0.005244   0.632231       0.0
# 3  0.668124  0.011958   0.525547       0.0
# 4  4.395720  0.005934   0.966184       0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# <h1>1. plot(x, y)  :  matplotlib.axes.Axes.plot</h1>
# <h3>Axes.plot(*args, scalex=True, scaley=True, data=None, **kwargs)</h3><br>
# Plot y versus x as lines and/or markers.

# %%
temp = data.iloc[:10]
x = temp["CPC"]
y = temp["CPM"]

fig, ax = plt.subplots()

ax.plot(x, y, alpha=0.5, linewidth=3)
# alpha : 투명도 조정
# linewidth : 선 굵기
